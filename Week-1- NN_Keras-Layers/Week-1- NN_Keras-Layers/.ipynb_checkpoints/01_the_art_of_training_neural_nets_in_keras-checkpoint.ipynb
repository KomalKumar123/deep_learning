# %% [markdown]
# # The Art of Training Neural Networks with Keras
#
# <br />
#
# ## Tools in the Deep Learning Ecosystem
#
# <img src="img/deep_learning_ecosystem.jpeg" />
#
# <br />
#
# * Hardware GPU vs CPU: At the core hardware level, we have CPUs and GPUs executing instructions.
#
#     <br />
#
#     * A CPU is able to execute large, sequential instructions but can only execute a small number of instructions parallelly
#
#     <br />
#
#     * A GPU can execute hundreds of small instructions parallelly
#
# <img src = 'img/cpu_vs_gpu.png' />
#
# * For deep learning where we have to do a bunch of linear algebraic computations parallelly, GPUs are exponentially faster than CPUs
#
# <br />
#
# * Compute Frameworks such as BLAS and CUDA help routine computations to be optimised for the specific processor instruction set for accelerated compute
#
#     <br />
#
#     * Basic Linear Algebra Subprograms are a bunch of routines that specify the low level routines for many linear algebraic operations. R, numpy, Matlab use BLAS to accelerate linear algebra operations. Ex: Intel's implementation of BLAS is known as Intel Math Kernel Library (MKL)
#
#     <br />
#
#     * CUDA is a framework created by NVIDIA that helps programmers write software to perform general purpose computing tasks on GPUs, most of the deep learning libraries use CUDA
#
# <br />
#
# * Libraries with support for Autodifferentiation to help in gradient computation for stacked layers were developed such as Theano, Tensorflow, CNTK and PyTorch.
#
# * These libraries are operations level (dot product, etc.) and the code is low level and hard to write for quick prototyping of new networks
#
# <br />
#
# <img src='img/deep_learning_frameworks.png' width='550px'/>
#
# <br />
#
# * That is wehre Keras comes into picture, it is a high level library with the abstraction at the __layer__ level. It was built as an abstraction to Theano and later support was added to Tensorflow and CNTK
#
# * So you can write code in Keras that can run on any of these three deep learning library __backends__

# %% [markdown]
# ## The Building Blocks of Neural Networks
#
# ### Layers, Data and Learning Representations
#
# <br />
#
# * __Layers__: logically grouped operations in a neural network, the parameters for the operations in the layer learn to generate the best features to predict the target
#
# <img src='img/nn_layers.jpeg' width='400px'/>
#
# <img src='img/nn_layer_operations.png' width='650px'/>
#
# <br />
#
# * The network needs to have __input data__ and corresponding __targets (y)__
#
# <br />
#
# * In traditional machine learning we see that changing the representation of the data (kernel trick, etc.) helps ease the process of learning from data
#
# <br />
#
# * __Activation function__ adds that non linearity and in combination with weights (parameters) of a layer, the network learns better representations of the data at each layer
#
# <br />
#
# ### So basically, each layer takes input as data and spits out transformed data as output, simple as that. Now, let's dive into the details
#
# <img src='img/learning_representations_mlp.jpg' />
#
# <br />
#
# * The goal of training neural networks is to find these perfect representation of data, which we get by "learning" the right weights
#
# <img src='img/learning_weights.jpg' />
#
# <br />
#
# * The loss function, which defines the feedback signal used for learning helps guage __how different are the targets and the predicted targets__
#
# <img src='img/loss_function.jpg' />
#
# <br />
#
# * The optimizer, based on the feedback signal from the loss function changes the parameters / weights of the network to help make the predictions as close to the target as possible (minimizing the loss function)
#
# <br />
#
# <img src='img/building_blocks_of_neural_networks.jpg' />

# %% [markdown]
# ## The Keras Interface
#
# <br />
#
# * There are two major ways to define and run neural netwroks using the Keras API
#
#     <br />
#
#     * Sequential API
#
#     <br />
#
#     * Functional API
#
# <br />
#
# ### The Sequential API
#
# * The sequential api allows us to __quickly stack layers__ and build networks
#
# <img src="img/keras_interface.jpg" width='550px'/>
#
# <br />
#
# <img src='img/keras_sequential_api.jpg' />
#
# <br />
#
# ### The Functional API
#
# * The functional api allows us to build complex graph networks, we can kee chaining the the layers as functions and finally the `Model(inputs, outputs)` class connects all the various inputs and outputs
#
# <br />
#
# <img src="img/functional_api_bimodal_network.png" width='450px'/>

# %% [raw]
# from keras.models import Model
# from keras.layers import Input, Conv2D, concatenate, LSTM, Embedding, Flatten, Dense
#
# input_one = Input(shape = (224, 224, 3))
# img_output = Conv2d(layer_params)(input_one)
# img_output = Flatten()(img_output)
#
# input_two = Input(input_shape = (len_max_tokens, 1))
# text_output = Embedding(layer_params)(input_two)
# text_output = LSTM(layer_params)(text_output)
# text_output = Flatten()(text_output)
#
# concat_output = concatenate()(img_output, text_output)
#
# output = Dense(layer_params)(concat_output)
# output = Dense(1, activation = 'linear')(output)
#
# model = Model(inputs = [input_one, input_two], outputs=output)

# %% [markdown]
# ## Layers in Keras

# %% [markdown]
# * There are different categories of layers in Keras, the most commonly used ones are "Dense Layers", "Convolution Layers", "Recurrent Layers", etc.

# %%
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
layer1 = Dense(units = 32, activation = 'sigmoid')

# %% [markdown]
# * Let's break down the above layer that we just built using the Dense class from keras
#
# <br />
#
# * The OUTPUT from the above layer can be given by `sigmoid ( dot ( W, INPUT ) + b )`, in the first round of training the W (weights) are randomly "initialized"
#
# <br />
#
# * Every input to the Dense layer (also known as fully connected) is connected to every unit in the hidden layer, as shown in the figure below
#
# <br />
#
# <img src ='img/fc_dense_layers_keras.jpg' />
#
# <br />
#
# * We will see many more categories and types of __Layers__ in keras, the __"Dense"__ layer is just one such class

# %% [markdown]
# ## Stacking the layers together : The Keras Sequential API
#
# <br />
#
# * The keras sequential api enables us to build common yet complex neural network architectures flexibly
#
# <br />
#
# * Objects of the Keras sequential class, can have multiple neural network layers stacked on top of one another
#
# <br />
#
# <img src='img/keras_sequential_api.jpg' />

# %% [markdown]
# * You can create a Keras sequential model by passing in a list of layers to the Sequential object

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential([
    Dense(32, input_shape=(784,), activation = 'sigmoid'),
    Dense(10, activation = 'sigmoid'),
    Dense(1, activation = 'sigmoid')
])

# %% [markdown]
# * But soon this becomes a problem to add more layers in a single list, so the "add" method on the sequential class object can add layers sequentially to the neural network

# %%
neural_network = Sequential()

neural_network.add(Dense(32, input_dim=784, activation = 'sigmoid',
                         kernel_initializer = 'zeros', bias_initializer = 'zeros'))

neural_network.add(Dense(10, activation = 'sigmoid', kernel_initializer = 'zeros',
                         bias_initializer = 'zeros'))

neural_network.add(Dense(1, activation = 'sigmoid', kernel_initializer = 'zeros',
                         bias_initializer = 'zeros'))

# %% [markdown]
# * The summary method on the neural network object gives us basic information about the structure of the network

# %%
neural_network.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_47 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_48 (Dense)             (None, 10)                330
# _________________________________________________________________
# dense_49 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 25,461
# Trainable params: 25,461
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# * That's all! Keras is that simple, initialize an object of the Sequential class, use the add method on that object to add layers to the network sequentially, but wait what about the loss function? what about the optimizer?

# %% [markdown]
# ## Building the same network using the Keras Functional API
#
# <br />
#
# * Essential keywords of the functional API: `Tensor, Callable Layers, Input, Model`
#
# <br />
#
# * The core data structure for the functional API is the `tensor`
#
# <br />
#
# * Once you have a tensor the others are just layers similar to the sequential API. But in the case of the functional API, the Layers become `callable` using round paranthesis just like we call a function, for example `function_name()`
#
# * The output of calling any `Layer` object in `Keras` is a `tensor`.
#
# We pass in a tensor to a layer, as follows
#
# ```
#                                      output_tensor = Layer(layer_params)(tensor)
#
# ```
#
# <br />
#
# * To pass our initial tensor, or the input data to the first layer, we have to create an input tensor, which we can by importing the `Input` class from the `keras.layers` submodule, as follows
#
# ```
#                                      from keras.layers import Input, Dense
#
#                                      input_tensor = Input(shape = (num_independent_vars, ))
#
#                                      first_layer_output = Dense(layer_params)(input_tensor)
#
#                                      output = Dense(final_layer_params)(first_layer_output)
#
# ```
#
# * Finally, we need to import the `Model` class from the `keras.models` submodule and mention the inputs and the outputs of the model, after which `Keras` very gracefully builds a model connecting the inputs to the outputs
#
# ```
#                                      from keras.models import Model
#
#                                      model = Model(inputs = input_tensor, outputs = output)
#
# ```

# %%
from keras.layers import Input, Dense
from keras.models import Model

input_tensor = Input(shape = (784,))

output = Dense(32, activation = 'sigmoid')(input_tensor)
output = Dense(10, activation = 'sigmoid')(output)
output = Dense(1, activation = 'sigmoid')(output)

model_functional = Model(inputs = input_tensor, outputs = output)

# %% [markdown]
# * The model summary looks the same, except for the inclusion of the Input Layer which creates the input tensor

# %%
model_functional.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 784)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_39 (Dense)             (None, 10)                330
# _________________________________________________________________
# dense_40 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 25,461
# Trainable params: 25,461
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Defining, Compiling and Running a Neural Network in Keras
#
# <br />
#
# ### The process of learning in a Neural Network
#
# <br />
#
# ### Loss Score
#
# <br />
#
# * The loss score is feedback signal that says how far is the output of your network compared to the ground truth
#
# <br />
#
# <img src='img/loss_function.jpg' />
#
# <br />
#
# * Two such loss scores that we use quite frequently are :
#
#     1) Binary Cross-Entropy: For Two-Class Classification problems
#
#     2) Mean Squared Error: For Regression problems
#
# <br />
#
# * We have already come across mean squared error before, so let's dive deeper into Binary Cross Entropy
#
# <br />
#
# $$\begin{eqnarray}
#   C = -\frac{1}{n} \sum_x \left[y \ln p + (1-y ) \ln (1-p) \right]
# \end{eqnarray}$$
#
# <br />
#
# * In the above equation, p is the output of the network, n is the total number of samples in the training data, the sum is over all training inputs, x, and y is the corresponding desired output
#
# <br />
#
# * Below, we see the value of the cross entropy (sometimes referred to as the log loss) changing with the predicted probability, we can see that the value of the loss for a prediction above 0.5 significantly drops and this helps the network converge much faster than using a traditional mean squared error
#
# <br />
#
# <img src='img/binary_cross_entropy.png' width='300px'/>

# %% [markdown]
# ## Optimizers
#
# <br />
#
# * An optimizer is an algorithm that uses the feedback signal from the loss function, to actually update the weights so that the output from the network gets closer to the ground truth. The first optimizer that we use is Stochastic Gradient Descent (SGD), we will slowly come across many more optimizers
#
# <br />
#
# * We can import Classes from the optimizers module of keras and customize the specific optimizer to our liking
#
# <br />
#
# <img src='img/building_blocks_of_neural_networks.jpg' />

# %% [markdown]
# * Please refer to this beautiful article written by Sebastian Ruder on the various iterations of the SGD optimizer http://ruder.io/optimizing-gradient-descent/
#
# <br />
#
# * Keras has the implementations of the following optimizers:
#     * SGD
#     * RMSprop
#     * Adagrad
#     * Adadelta
#     * Adam
#     * Adamax
#     * Nadam

# %%
from keras.optimizers import SGD

customized_optimizer = SGD(lr = 0.0001)

# %% [markdown]
# * We already know how learning rate can effect convergence, the graph below provides a decent intuition, hence having the flexibility to change the learning rate is very important

# %% [markdown]
# ![](img/learning_rate.jpg)

# %% [markdown]
# ## Compiling the neural network ( loss function + optimizer)

# %%
neural_network = Sequential()

neural_network.add(Dense(32, input_dim=784, activation = 'sigmoid',
                         kernel_initializer = 'RandomUniform', bias_initializer = 'zeros'))

neural_network.add(Dense(10, activation = 'sigmoid', kernel_initializer = 'zeros',
                         bias_initializer = 'RandomUniform'))

neural_network.add(Dense(1, activation = 'sigmoid', kernel_initializer = 'zeros',
                         bias_initializer = 'RandomUniform'))

neural_network.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_53 (Dense)             (None, 32)                25120
# _________________________________________________________________
# dense_54 (Dense)             (None, 10)                330
# _________________________________________________________________
# dense_55 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 25,461
# Trainable params: 25,461
# Non-trainable params: 0
# _________________________________________________________________

# %%
# neural_network.compile(loss = 'binary_crossentropy', optimizer = 'sgd', metrics = ['accuracy'])

# %%
from keras.optimizers import SGD

customized_optimizer = SGD(lr = 0.0001)

# %%
neural_network.compile(loss = 'binary_crossentropy', optimizer = customized_optimizer, metrics = ['accuracy'])

# %% [markdown]
# * As we can see from the compile step above we need to specify the loss function, optimization algorithm and we can also mention the metrics that we want to monitor while training the neural network
#
# <br />
#
# * Also, please __note__ that the optimizer argument can either be a string or a customizable object from the optimizers module in Keras

# %% [markdown]
# ## So are we done? what about learning the weights?
#
# <br />
#
# * Training the network in Keras is also very simple, we call the `.fit()` method and pass in the arguments
#
# <br />
#
# * Some important terms for training neural networks are epochs, batch_size

# %% [raw]
# # NOTE : Don't run the following line of code as we do not yet have X_train and y_train
#
# neural_network.fit(X_train, y_train, epochs=100, batch_size=64)

# %% [markdown]
# ### Download the MNIST dataset using the Keras helper function

# %%
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %% [markdown]
# ### The dataset consist of images represented as
#
# ![](img/mnist_representation.png)

# %%
print(X_train.shape)
# Out:
# (60000, 28, 28)

# %%
## Reshape the images from 28 * 28 to 284

X_train = X_train.reshape(-1, 28*28)

# %%
print(X_test.shape)
# Out:
# (10000, 28, 28)

# %%
## Reshape the images from 28 * 28 to 284

X_test = X_test.reshape(-1, 28*28)

# %%
training_history = neural_network.fit(X_train, y_train, epochs=100, batch_size=1024, validation_split=0.2)
# Out:
# Train on 48000 samples, validate on 12000 samples
# Epoch 1/100
# 48000/48000 [==============================] - 0s 10us/step - loss: 0.4669 - accuracy: 0.1140 - val_loss: 0.3340 - val_accuracy: 0.1060
# Epoch 2/100
# 48000/48000 [==============================] - 0s 6us/step - loss: 0.2113 - accuracy: 0.1140 - val_loss: 0.0782 - val_accuracy: 0.1060
# Epoch 3/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -0.0424 - accuracy: 0.1140 - val_loss: -0.1759 - val_accuracy: 0.1060
# Epoch 4/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -0.2946 - accuracy: 0.1140 - val_loss: -0.4287 - val_accuracy: 0.1060
# Epoch 5/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -0.5455 - accuracy: 0.1140 - val_loss: -0.6802 - val_accuracy: 0.1060
# Epoch 6/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -0.7953 - accuracy: 0.1140 - val_loss: -0.9307 - val_accuracy: 0.1060
# Epoch 7/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -1.0442 - accuracy: 0.1140 - val_loss: -1.1804 - val_accuracy: 0.1060
# Epoch 8/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -1.2924 - accuracy: 0.1140 - val_loss: -1.4296 - val_accuracy: 0.1060
# Epoch 9/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -1.5402 - accuracy: 0.1140 - val_loss: -1.6785 - val_accuracy: 0.1060
# Epoch 10/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -1.7877 - accuracy: 0.1140 - val_loss: -1.9272 - val_accuracy: 0.1060
# Epoch 11/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -2.0351 - accuracy: 0.1140 - val_loss: -2.1760 - val_accuracy: 0.1060
# Epoch 12/100
# 48000/48000 [==============================] - 0s 8us/step - loss: -2.2828 - accuracy: 0.1140 - val_loss: -2.4250 - val_accuracy: 0.1060
# Epoch 13/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -2.5308 - accuracy: 0.1140 - val_loss: -2.6746 - val_accuracy: 0.1060
# Epoch 14/100
# 48000/48000 [==============================] - 0s 9us/step - loss: -2.7794 - accuracy: 0.1140 - val_loss: -2.9249 - val_accuracy: 0.1060
# Epoch 15/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -3.0289 - accuracy: 0.1140 - val_loss: -3.1762 - val_accuracy: 0.1060
# Epoch 16/100
# 48000/48000 [==============================] - 0s 8us/step - loss: -3.2794 - accuracy: 0.1140 - val_loss: -3.4287 - val_accuracy: 0.1060
# Epoch 17/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -3.5312 - accuracy: 0.1140 - val_loss: -3.6826 - val_accuracy: 0.1060
# Epoch 18/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -3.7846 - accuracy: 0.1140 - val_loss: -3.9383 - val_accuracy: 0.1060
# Epoch 19/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -4.0399 - accuracy: 0.1140 - val_loss: -4.1960 - val_accuracy: 0.1060
# Epoch 20/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -4.2973 - accuracy: 0.1140 - val_loss: -4.4560 - val_accuracy: 0.1060
# Epoch 21/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -4.5571 - accuracy: 0.1140 - val_loss: -4.7186 - val_accuracy: 0.1060
# Epoch 22/100
# 48000/48000 [==============================] - 0s 8us/step - loss: -4.8198 - accuracy: 0.1140 - val_loss: -4.9842 - val_accuracy: 0.1060
# Epoch 23/100
# 48000/48000 [==============================] - 0s 8us/step - loss: -5.0855 - accuracy: 0.1140 - val_loss: -5.2531 - val_accuracy: 0.1060
# Epoch 24/100
# 48000/48000 [==============================] - 0s 9us/step - loss: -5.3547 - accuracy: 0.1140 - val_loss: -5.5258 - val_accuracy: 0.1060
# Epoch 25/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -5.6279 - accuracy: 0.1140 - val_loss: -5.8026 - val_accuracy: 0.1060
# Epoch 26/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -5.9054 - accuracy: 0.1140 - val_loss: -6.0841 - val_accuracy: 0.1060
# Epoch 27/100
# 48000/48000 [==============================] - 0s 9us/step - loss: -6.1878 - accuracy: 0.1140 - val_loss: -6.3707 - val_accuracy: 0.1060
# Epoch 28/100
# 48000/48000 [==============================] - 0s 9us/step - loss: -6.4755 - accuracy: 0.1140 - val_loss: -6.6630 - val_accuracy: 0.1060
# Epoch 29/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -6.7691 - accuracy: 0.1140 - val_loss: -6.9615 - val_accuracy: 0.1060
# Epoch 30/100
# 48000/48000 [==============================] - 0s 9us/step - loss: -7.0693 - accuracy: 0.1140 - val_loss: -7.2669 - val_accuracy: 0.1060
# Epoch 31/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -7.3763 - accuracy: 0.1140 - val_loss: -7.5797 - val_accuracy: 0.1060
# Epoch 32/100
# 48000/48000 [==============================] - 0s 9us/step - loss: -7.6909 - accuracy: 0.1140 - val_loss: -7.9005 - val_accuracy: 0.1060
# Epoch 33/100
# 48000/48000 [==============================] - 0s 10us/step - loss: -8.0137 - accuracy: 0.1140 - val_loss: -8.2297 - val_accuracy: 0.1060
# Epoch 34/100
# 48000/48000 [==============================] - 0s 10us/step - loss: -8.3453 - accuracy: 0.1140 - val_loss: -8.5678 - val_accuracy: 0.1060
# Epoch 35/100
# 48000/48000 [==============================] - 0s 8us/step - loss: -8.6859 - accuracy: 0.1140 - val_loss: -8.9152 - val_accuracy: 0.1060
# Epoch 36/100
# 48000/48000 [==============================] - 0s 9us/step - loss: -9.0366 - accuracy: 0.1140 - val_loss: -9.2728 - val_accuracy: 0.1060
# Epoch 37/100
# 48000/48000 [==============================] - 0s 9us/step - loss: -9.3976 - accuracy: 0.1140 - val_loss: -9.6408 - val_accuracy: 0.1060
# Epoch 38/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -9.7693 - accuracy: 0.1140 - val_loss: -10.0202 - val_accuracy: 0.1060
# Epoch 39/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -10.1519 - accuracy: 0.1140 - val_loss: -10.4111 - val_accuracy: 0.1060
# Epoch 40/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -10.5458 - accuracy: 0.1140 - val_loss: -10.8133 - val_accuracy: 0.1060
# Epoch 41/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -10.9515 - accuracy: 0.1140 - val_loss: -11.2272 - val_accuracy: 0.1060
# Epoch 42/100
# 48000/48000 [==============================] - 0s 9us/step - loss: -11.3682 - accuracy: 0.1140 - val_loss: -11.6523 - val_accuracy: 0.1060
# Epoch 43/100
# 48000/48000 [==============================] - 0s 9us/step - loss: -11.7963 - accuracy: 0.1140 - val_loss: -12.0892 - val_accuracy: 0.1060
# Epoch 44/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -12.2361 - accuracy: 0.1140 - val_loss: -12.5376 - val_accuracy: 0.1060
# Epoch 45/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -12.6878 - accuracy: 0.1140 - val_loss: -12.9978 - val_accuracy: 0.1060
# Epoch 46/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -13.1512 - accuracy: 0.1140 - val_loss: -13.4691 - val_accuracy: 0.1060
# Epoch 47/100
# 48000/48000 [==============================] - 0s 8us/step - loss: -13.6251 - accuracy: 0.1140 - val_loss: -13.9507 - val_accuracy: 0.1060
# Epoch 48/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -14.1090 - accuracy: 0.1140 - val_loss: -14.4426 - val_accuracy: 0.1060
# Epoch 49/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -14.6028 - accuracy: 0.1140 - val_loss: -14.9442 - val_accuracy: 0.1060
# Epoch 50/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -15.1062 - accuracy: 0.1140 - val_loss: -15.4550 - val_accuracy: 0.1060
# Epoch 51/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -15.6187 - accuracy: 0.1140 - val_loss: -15.9747 - val_accuracy: 0.1060
# Epoch 52/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -16.1398 - accuracy: 0.1140 - val_loss: -16.5027 - val_accuracy: 0.1060
# Epoch 53/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -16.6685 - accuracy: 0.1140 - val_loss: -17.0385 - val_accuracy: 0.1060
# Epoch 54/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -17.2046 - accuracy: 0.1140 - val_loss: -17.5811 - val_accuracy: 0.1060
# Epoch 55/100
# 48000/48000 [==============================] - 1s 11us/step - loss: -17.7475 - accuracy: 0.1140 - val_loss: -18.1307 - val_accuracy: 0.1060
# Epoch 56/100
# 48000/48000 [==============================] - 1s 12us/step - loss: -18.2971 - accuracy: 0.1140 - val_loss: -18.6862 - val_accuracy: 0.1060
# Epoch 57/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -18.8530 - accuracy: 0.1140 - val_loss: -19.2481 - val_accuracy: 0.1060
# Epoch 58/100
# 48000/48000 [==============================] - 0s 10us/step - loss: -19.4150 - accuracy: 0.1140 - val_loss: -19.8159 - val_accuracy: 0.1060
# Epoch 59/100
# 48000/48000 [==============================] - 0s 8us/step - loss: -19.9824 - accuracy: 0.1140 - val_loss: -20.3891 - val_accuracy: 0.1060
# Epoch 60/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -20.5547 - accuracy: 0.1140 - val_loss: -20.9667 - val_accuracy: 0.1060
# Epoch 61/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -21.1315 - accuracy: 0.1140 - val_loss: -21.5484 - val_accuracy: 0.1060
# Epoch 62/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -21.7125 - accuracy: 0.1140 - val_loss: -22.1348 - val_accuracy: 0.1060
# Epoch 63/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -22.2978 - accuracy: 0.1140 - val_loss: -22.7252 - val_accuracy: 0.1060
# Epoch 64/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -22.8867 - accuracy: 0.1140 - val_loss: -23.3193 - val_accuracy: 0.1060
# Epoch 65/100
# 48000/48000 [==============================] - 0s 9us/step - loss: -23.4792 - accuracy: 0.1140 - val_loss: -23.9166 - val_accuracy: 0.1060
# Epoch 66/100
# 48000/48000 [==============================] - 0s 8us/step - loss: -24.0748 - accuracy: 0.1140 - val_loss: -24.5171 - val_accuracy: 0.1060
# Epoch 67/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -24.6733 - accuracy: 0.1140 - val_loss: -25.1204 - val_accuracy: 0.1060
# Epoch 68/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -25.2744 - accuracy: 0.1140 - val_loss: -25.7260 - val_accuracy: 0.1060
# Epoch 69/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -25.8777 - accuracy: 0.1140 - val_loss: -26.3335 - val_accuracy: 0.1060
# Epoch 70/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -26.4829 - accuracy: 0.1140 - val_loss: -26.9425 - val_accuracy: 0.1060
# Epoch 71/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -27.0895 - accuracy: 0.1140 - val_loss: -27.5536 - val_accuracy: 0.1060
# Epoch 72/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -27.6977 - accuracy: 0.1140 - val_loss: -28.1661 - val_accuracy: 0.1060
# Epoch 73/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -28.3075 - accuracy: 0.1140 - val_loss: -28.7797 - val_accuracy: 0.1060
# Epoch 74/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -28.9182 - accuracy: 0.1140 - val_loss: -29.3941 - val_accuracy: 0.1060
# Epoch 75/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -29.5301 - accuracy: 0.1140 - val_loss: -30.0094 - val_accuracy: 0.1060
# Epoch 76/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -30.1427 - accuracy: 0.1140 - val_loss: -30.6256 - val_accuracy: 0.1060
# Epoch 77/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -30.7558 - accuracy: 0.1140 - val_loss: -31.2424 - val_accuracy: 0.1060
# Epoch 78/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -31.3694 - accuracy: 0.1140 - val_loss: -31.8594 - val_accuracy: 0.1060
# Epoch 79/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -31.9832 - accuracy: 0.1140 - val_loss: -32.4769 - val_accuracy: 0.1060
# Epoch 80/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -32.5975 - accuracy: 0.1140 - val_loss: -33.0948 - val_accuracy: 0.1060
# Epoch 81/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -33.2121 - accuracy: 0.1140 - val_loss: -33.7130 - val_accuracy: 0.1060
# Epoch 82/100
# 48000/48000 [==============================] - 0s 8us/step - loss: -33.8269 - accuracy: 0.1140 - val_loss: -34.3316 - val_accuracy: 0.1060
# Epoch 83/100
# 48000/48000 [==============================] - 0s 8us/step - loss: -34.4422 - accuracy: 0.1140 - val_loss: -34.9504 - val_accuracy: 0.1060
# Epoch 84/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -35.0578 - accuracy: 0.1140 - val_loss: -35.5693 - val_accuracy: 0.1060
# Epoch 85/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -35.6733 - accuracy: 0.1140 - val_loss: -36.1885 - val_accuracy: 0.1060
# Epoch 86/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -36.2892 - accuracy: 0.1140 - val_loss: -36.8077 - val_accuracy: 0.1060
# Epoch 87/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -36.9051 - accuracy: 0.1140 - val_loss: -37.4271 - val_accuracy: 0.1060
# Epoch 88/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -37.5211 - accuracy: 0.1140 - val_loss: -38.0467 - val_accuracy: 0.1060
# Epoch 89/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -38.1373 - accuracy: 0.1140 - val_loss: -38.6663 - val_accuracy: 0.1060
# Epoch 90/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -38.7536 - accuracy: 0.1140 - val_loss: -39.2859 - val_accuracy: 0.1060
# Epoch 91/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -39.3699 - accuracy: 0.1140 - val_loss: -39.9056 - val_accuracy: 0.1060
# Epoch 92/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -39.9863 - accuracy: 0.1140 - val_loss: -40.5254 - val_accuracy: 0.1060
# Epoch 93/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -40.6028 - accuracy: 0.1140 - val_loss: -41.1453 - val_accuracy: 0.1060
# Epoch 94/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -41.2193 - accuracy: 0.1140 - val_loss: -41.7654 - val_accuracy: 0.1060
# Epoch 95/100
# 48000/48000 [==============================] - 0s 10us/step - loss: -41.8360 - accuracy: 0.1140 - val_loss: -42.3854 - val_accuracy: 0.1060
# Epoch 96/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -42.4527 - accuracy: 0.1140 - val_loss: -43.0055 - val_accuracy: 0.1060
# Epoch 97/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -43.0693 - accuracy: 0.1140 - val_loss: -43.6255 - val_accuracy: 0.1060
# Epoch 98/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -43.6860 - accuracy: 0.1140 - val_loss: -44.2457 - val_accuracy: 0.1060
# Epoch 99/100
# 48000/48000 [==============================] - 0s 7us/step - loss: -44.3027 - accuracy: 0.1140 - val_loss: -44.8657 - val_accuracy: 0.1060
# Epoch 100/100
# 48000/48000 [==============================] - 0s 6us/step - loss: -44.9194 - accuracy: 0.1140 - val_loss: -45.4858 - val_accuracy: 0.1060

# %% [markdown]
# ## Plotting the training process of the neural network
#
# <br />
#
# * Once, we write the code for plotting the loss and accuracy while training our network, we will functionalize the code to make it easy for us to very quickly visualize the training metrics of our network.
#
# <br />

# %%
from matplotlib import pyplot as plt

plt.plot(training_history.history['accuracy'])
plt.plot(training_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(training_history.history['loss'])
plt.plot(training_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Function to plot metrics after training

def plot_training_metrics(history_object, metric = 'loss', val = True):
    
    plt.plot(history_object.history[metric])
    
    if val == True:
        plt.plot(history_object.history['val_' + metric])
    
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
plot_training_metrics(training_history)

# %%
plot_training_metrics(training_history, metric = 'accuracy')

# %% [markdown]
# * An __Epoch__ is when an ENTIRE dataset is passed forward and backward through the neural network only once.
#
# <br />
#
# * Since most of the times an epoch is too large to fit in memory, we divide the data into batches and compute the gradient on batches for each forward and backward pass
#
# <br />
#
# * __Batch size__ is the number of samples that are going to be propagated through the network.
#
# <br />
#
# <img src='img/learning_rate_epochs_rel.png' width='400px'/>

# %% [markdown]
# ## Neural Network Architectures for Basic ML Tasks
#
# <br />
#
# <img src='img/nn_for_basic_ml_tasks.jpg' width='800px'/>

# %% [markdown]
# ## Exercise & Experiment
#
# <br />
#
# * Use different activation functions, report difference in metrics while training
#
# __Different experiments to run: 'sigmoid', 'tanh', 'relu'__
#
# <br />
#
# * Use different weight initialization functions, report difference in metrics while training
#
# __Different experiments to run: 'zeros', 'RandomUniform', 'RandomNormal', 'glorot_normal', 'glorot_uniform', 'he_normal', 'lecun_normal', 'he_uniform'__
#
# <br />
#
# * Use different number of layers, number of nodes and report difference in metrics while training
#
# __Different experiments to run: more nodes or more layers?__
#
#
# <br />
#
# * Use BatchNormalization, report difference in metrics while training, if you have to add batchnorm after a layer just do as follows
#
# ```
#
# from keras.layers import BatchNormalization
#
# model.add(Dense(layer_params))
#
# model.add(BatchNormalization())
#
# model.add(Dense(layer_params))
#
# ```
#
# <br />
#
# * Use different Dropout rates, report difference in metrics while training
#
# ```
# from keras.layers import Dropout
#
# model.add(Dense(layer_params))
#
# model.add(Dropout(rate = 0.4))
#
# model.add(Dense(layer_params))
#
# ```
#
# <br />
#
# * Use different learning rates and optimizers, report difference in metrics while training
#
# <br />
